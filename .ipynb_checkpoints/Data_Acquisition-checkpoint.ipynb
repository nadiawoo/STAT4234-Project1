# %% [markdown]
# ###Testing Spotipy-facilitated API calls (did not work)

# %%
# !pip install spotipy #this is a lightweight Python library that allows us to access the Spotify web API with python
# Out:
# Requirement already satisfied: spotipy in /usr/local/lib/python3.11/dist-packages (2.25.0)
# Requirement already satisfied: redis>=3.5.3 in /usr/local/lib/python3.11/dist-packages (from spotipy) (5.2.1)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.11/dist-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from spotipy) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->spotipy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->spotipy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->spotipy) (2025.1.31)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id = "846863b7c91a45e0b32f787dde9ae429"
client_secret = "3aa4a64d9ca64a3a8b429e07af58a8ca"
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
#testing if this works
name = ["Micheal Jackson","pitbull","Christina","Elvis Presley"] #using a manual list of artists
result = sp.search(name)

artists_uris = result['tracks']['items'][0]['artists'][0]['uri'] #this can be made into a loop for i in name

#Pull all of the artist's albums
artist_albums = sp.artist_albums(artists_uris, album_type='album')

#Store artist's albums' names' and uris in separate lists
artist_album_names = []
artist_album_uris = []
for i in range(len(artist_albums['items'])):
    artist_album_names.append(artist_albums['items'][i]['name'])
    artist_album_uris.append(artist_albums['items'][i]['uri'])

artist_album_names
artist_album_uris
#Keep names and uris in same order to keep track of duplicate albums
# Out:
# ['spotify:album:57TzZhbqvYoUBzJSVKFVlG',
#  'spotify:album:54WFfZzds26NrwcmStfamd',
#  'spotify:album:7pomP86PUhoJpY3fsC0WDQ',
#  'spotify:album:24TAupSNVWSAHL0R7n71vm',
#  'spotify:album:5S7ySBYbWKsZdVYQrNtrWf',
#  'spotify:album:1C2h7mLntPSeVYciMRTF4a',
#  'spotify:album:52E4RP7XDzalpIrOgSTgiQ',
#  'spotify:album:0RNsFWWdiz1rrdLI1pwbvJ',
#  'spotify:album:3OBhnTLrvkoEEETjFA3Qfk',
#  'spotify:album:0oX4SealMgNXrvRDhqqOKg',
#  'spotify:album:3Us57CjssWnHjTUIXBuIeH',
#  'spotify:album:2ANVost0y2y52ema1E9xAZ',
#  'spotify:album:2ZytN2cY4Zjrr9ukb2rqTP',
#  'spotify:album:6leeBdAohG7zhybC3Cmu8W',
#  'spotify:album:19vhLDr0Fw8Lja1I8xVV09',
#  'spotify:album:3xo2soey9XEBI5DlmT4KlQ',
#  'spotify:album:0F4XW0iBOhNFkbn1BuQ8cu']

# %%
artist_album_names
# Out:
# ['Thriller 40',
#  'XSCAPE - Track by Track Commentary',
#  'XSCAPE',
#  'Bad 25th Anniversary',
#  'Michael',
#  'Thriller 25 Super Deluxe Edition',
#  'Invincible',
#  'BLOOD ON THE DANCE FLOOR/ HIStory In The Mix',
#  'HIStory - PAST, PRESENT AND FUTURE - BOOK I',
#  'Dangerous',
#  'Bad (Remastered)',
#  'Thriller',
#  'Off the Wall',
#  'Forever, Michael',
#  'Music and Me',
#  'Ben',
#  'Got To Be There']

# %%
#supposedly we now collected all of the artist of interest and their album name and uris, we can now retreive each song of album
def album_songs(uri):
    album = uri
    spotify_albums[album] = {}
    #Create keys-values of empty lists inside nested dictionary for album
    spotify_albums[album]['album'] = []
    spotify_albums[album]['track_number'] = []
    spotify_albums[album]['id'] = []
    spotify_albums[album]['name'] = []
    spotify_albums[album]['uri'] = []
    #pull data on album tracks
    tracks = sp.album_tracks(album)
    for n in range(len(tracks['items'])):
        spotify_albums[album]['album'].append(artist_album_names[album_count])
        spotify_albums[album]['track_number'].append(tracks['items'][n]['track_number'])
        spotify_albums[album]['id'].append(tracks['items'][n]['id'])
        spotify_albums[album]['name'].append(tracks['items'][n]['name'])
        spotify_albums[album]['uri'].append(tracks['items'][n]['uri'])

spotify_albums = {}
album_count = 0
for i in artist_album_uris: #each album
    album_songs(i)
    print(str(artist_album_names[album_count]) + " album songs has been added to spotify_albums dictionary")
    album_count+=1 #Updates album count once all tracks have been added

spotify_albums = {}
album_count = 0
for i in artist_album_uris: #each album
    album_songs(i)
    print(str(artist_album_names[album_count]) + " album songs has been added to spotify_albums dictionary")
    album_count+=1 #Updates album count once all tracks have been added
# Out:
# Thriller 40 album songs has been added to spotify_albums dictionary
# XSCAPE - Track by Track Commentary album songs has been added to spotify_albums dictionary
# XSCAPE album songs has been added to spotify_albums dictionary
# Bad 25th Anniversary album songs has been added to spotify_albums dictionary
# Michael album songs has been added to spotify_albums dictionary
# Thriller 25 Super Deluxe Edition album songs has been added to spotify_albums dictionary
# Invincible album songs has been added to spotify_albums dictionary
# BLOOD ON THE DANCE FLOOR/ HIStory In The Mix album songs has been added to spotify_albums dictionary
# HIStory - PAST, PRESENT AND FUTURE - BOOK I album songs has been added to spotify_albums dictionary
# Dangerous album songs has been added to spotify_albums dictionary
# Bad (Remastered) album songs has been added to spotify_albums dictionary
# Thriller album songs has been added to spotify_albums dictionary
# Off the Wall album songs has been added to spotify_albums dictionary
# Forever, Michael album songs has been added to spotify_albums dictionary
# Music and Me album songs has been added to spotify_albums dictionary
# Ben album songs has been added to spotify_albums dictionary
# Got To Be There album songs has been added to spotify_albums dictionary
# Thriller 40 album songs has been added to spotify_albums dictionary
# XSCAPE - Track by Track Commentary album songs has been added to spotify_albums dictionary
# XSCAPE album songs has been added to spotify_albums dictionary
# Bad 25th Anniversary album songs has been added to spotify_albums dictionary
# Michael album songs has been added to spotify_albums dictionary
# Thriller 25 Super Deluxe Edition album songs has been added to spotify_albums dictionary
# Invincible album songs has been added to spotify_albums dictionary
# BLOOD ON THE DANCE FLOOR/ HIStory In The Mix album songs has been added to spotify_albums dictionary
# HIStory - PAST, PRESENT AND FUTURE - BOOK I album songs has been added to spotify_albums dictionary
# Dangerous album songs has been added to spotify_albums dictionary
# Bad (Remastered) album songs has been added to spotify_albums dictionary
# Thriller album songs has been added to spotify_albums dictionary
# Off the Wall album songs has been added to spotify_albums dictionary
# Forever, Michael album songs has been added to spotify_albums dictionary
# Music and Me album songs has been added to spotify_albums dictionary
# Ben album songs has been added to spotify_albums dictionary
# Got To Be There album songs has been added to spotify_albums dictionary

# %% [markdown]
# **Instead of choosing a list of artists, with the code below I am trying an alternative way to get as much artists as possible**

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)


#testing
results = sp.search(q="taylor", type="track", limit=1)
track = results["tracks"]["items"][0]
print("Song Name:", track["name"])
print("Artist:", track["artists"][0]["name"])
print("Spotify URL:", track["external_urls"]["spotify"])
# Out:
# Song Name: You Belong With Me
# Artist: Taylor Swift
# Spotify URL: https://open.spotify.com/track/3GCL1PydwsLodcpv0Ll1ch

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import time
import pandas as pd

# Authenticate with Spotify API
auth_manager = SpotifyClientCredentials()
sp = spotipy.Spotify(auth_manager=auth_manager)

# Define genres of interest
genres = ["pop", "hip-hop", "rock", "jazz", "country", "electronic", "reggae", "blues", "r&b", "metal"]

# Define search prefixes to bypass Spotify's 1000-result limit
search_prefixes = list("ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789")  # A-Z, 0-9

# Store unique artist IDs to prevent duplicates
artist_ids = set()

# Loop through all genres
for genre in genres:
    print(f"🔍 Searching for artists in the '{genre}' genre...")

    for prefix in search_prefixes:
        offset = 0

        while offset < 1000:  # Ensure we stay within Spotify's 1000-item limit
            query = f"genre:{genre} artist:{prefix}*"
            try:
                results = sp.search(q=query, type="artist", limit=50, offset=offset)
                artists = results["artists"]["items"]

                if not artists:  # Stop if no more artists are found
                    break

                for artist in artists:
                    artist_ids.add(artist["id"])  # Store unique artist IDs

                print(f"✅ {genre} ({prefix}*): {len(artist_ids)} unique artists collected.")

                offset += 50  # Move to next page
                time.sleep(0.5)  # Prevent hitting API rate limits

            except Exception as e:
                print(f"⚠️ Error occurred at offset {offset} for {genre} ({prefix}*): {e}")
                break  # Stop on error and continue to next prefix

print(f"\n🎉 Total unique artists collected: {len(artist_ids)}") #due to search limit, it gotten to metal (9*): 88735
# Out:
# 🔍 Searching for artists in the 'pop' genre...
# ✅ pop (A*): 50 unique artists collected.
# ✅ pop (A*): 100 unique artists collected.
# ✅ pop (A*): 150 unique artists collected.
# ✅ pop (A*): 200 unique artists collected.
# ✅ pop (A*): 250 unique artists collected.
# ✅ pop (A*): 300 unique artists collected.
# ✅ pop (A*): 350 unique artists collected.
# ✅ pop (A*): 400 unique artists collected.
# ✅ pop (A*): 450 unique artists collected.
# ✅ pop (A*): 500 unique artists collected.
# ✅ pop (A*): 550 unique artists collected.
# ✅ pop (A*): 600 unique artists collected.
# ✅ pop (A*): 650 unique artists collected.
# ✅ pop (A*): 700 unique artists collected.
# ✅ pop (A*): 750 unique artists collected.
# ✅ pop (A*): 800 unique artists collected.
# ✅ pop (A*): 850 unique artists collected.
# ✅ pop (A*): 900 unique artists collected.
# ✅ pop (A*): 950 unique artists collected.
# ✅ pop (A*): 1000 unique artists collected.
# ✅ pop (B*): 1047 unique artists collected.
# ✅ pop (B*): 1094 unique artists collected.
# ✅ pop (B*): 1138 unique artists collected.
# ✅ pop (B*): 1183 unique artists collected.
# ✅ pop (B*): 1229 unique artists collected.
# ✅ pop (B*): 1276 unique artists collected.
# ✅ pop (B*): 1322 unique artists collected.
# ✅ pop (B*): 1370 unique artists collected.
# ✅ pop (B*): 1415 unique artists collected.
# ✅ pop (B*): 1458 unique artists collected.
# ✅ pop (B*): 1504 unique artists collected.
# ✅ pop (B*): 1551 unique artists collected.
# ✅ pop (B*): 1596 unique artists collected.
# ✅ pop (B*): 1642 unique artists collected.
# ✅ pop (B*): 1685 unique artists collected.
# ✅ pop (B*): 1733 unique artists collected.
# ✅ pop (B*): 1778 unique artists collected.
# ✅ pop (B*): 1828 unique artists collected.
# ✅ pop (B*): 1878 unique artists collected.
# ✅ pop (B*): 1928 unique artists collected.
# ✅ pop (C*): 1973 unique artists collected.
# ✅ pop (C*): 2019 unique artists collected.
# ✅ pop (C*): 2058 unique artists collected.
# ✅ pop (C*): 2103 unique artists collected.
# ✅ pop (C*): 2144 unique artists collected.
# ✅ pop (C*): 2186 unique artists collected.
# ✅ pop (C*): 2228 unique artists collected.
# ✅ pop (C*): 2269 unique artists collected.
# ✅ pop (C*): 2315 unique artists collected.
# ✅ pop (C*): 2359 unique artists collected.
# ✅ pop (C*): 2403 unique artists collected.
# ✅ pop (C*): 2444 unique artists collected.
# ✅ pop (C*): 2485 unique artists collected.
# ✅ pop (C*): 2525 unique artists collected.
# ✅ pop (C*): 2572 unique artists collected.
# ✅ pop (C*): 2615 unique artists collected.
# ✅ pop (C*): 2662 unique artists collected.
# ✅ pop (C*): 2707 unique artists collected.
# ✅ pop (C*): 2757 unique artists collected.
# ✅ pop (C*): 2807 unique artists collected.
# ✅ pop (D*): 2850 unique artists collected.
# ✅ pop (D*): 2894 unique artists collected.
# ✅ pop (D*): 2936 unique artists collected.
# ✅ pop (D*): 2967 unique artists collected.
# ✅ pop (D*): 3007 unique artists collected.
# ✅ pop (D*): 3046 unique artists collected.
# ✅ pop (D*): 3084 unique artists collected.
# ✅ pop (D*): 3126 unique artists collected.
# ✅ pop (D*): 3160 unique artists collected.
# ✅ pop (D*): 3204 unique artists collected.
# ✅ pop (D*): 3245 unique artists collected.
# ✅ pop (D*): 3281 unique artists collected.
# ✅ pop (D*): 3319 unique artists collected.
# ✅ pop (D*): 3354 unique artists collected.
# ✅ pop (D*): 3398 unique artists collected.
# ✅ pop (D*): 3441 unique artists collected.
# ✅ pop (D*): 3488 unique artists collected.
# ✅ pop (D*): 3532 unique artists collected.
# ✅ pop (D*): 3582 unique artists collected.
# ✅ pop (D*): 3632 unique artists collected.
# ✅ pop (E*): 3656 unique artists collected.
# ✅ pop (E*): 3683 unique artists collected.
# ✅ pop (E*): 3712 unique artists collected.
# ✅ pop (E*): 3739 unique artists collected.
# ✅ pop (E*): 3766 unique artists collected.
# ✅ pop (E*): 3792 unique artists collected.
# ✅ pop (E*): 3824 unique artists collected.
# ✅ pop (E*): 3853 unique artists collected.
# ✅ pop (E*): 3882 unique artists collected.
# ✅ pop (E*): 3906 unique artists collected.
# ✅ pop (E*): 3940 unique artists collected.
# ✅ pop (E*): 3976 unique artists collected.
# ✅ pop (E*): 4023 unique artists collected.
# ✅ pop (E*): 4070 unique artists collected.
# ✅ pop (E*): 4117 unique artists collected.
# ✅ pop (E*): 4167 unique artists collected.
# ✅ pop (E*): 4217 unique artists collected.
# ✅ pop (E*): 4267 unique artists collected.
# ✅ pop (E*): 4317 unique artists collected.
# ✅ pop (E*): 4367 unique artists collected.
# ✅ pop (F*): 4404 unique artists collected.
# ✅ pop (F*): 4436 unique artists collected.
# ✅ pop (F*): 4466 unique artists collected.
# ✅ pop (F*): 4504 unique artists collected.
# ✅ pop (F*): 4531 unique artists collected.
# ✅ pop (F*): 4567 unique artists collected.
# ✅ pop (F*): 4601 unique artists collected.
# ✅ pop (F*): 4640 unique artists collected.
# ✅ pop (F*): 4677 unique artists collected.
# ✅ pop (F*): 4712 unique artists collected.
# ✅ pop (F*): 4756 unique artists collected.
# ✅ pop (F*): 4802 unique artists collected.
# ✅ pop (F*): 4848 unique artists collected.
# ✅ pop (F*): 4894 unique artists collected.
# ✅ pop (F*): 4941 unique artists collected.
# ✅ pop (F*): 4987 unique artists collected.
# ✅ pop (F*): 5037 unique artists collected.
# ✅ pop (F*): 5087 unique artists collected.
# ✅ pop (F*): 5137 unique artists collected.
# ✅ pop (F*): 5187 unique artists collected.
# ✅ pop (G*): 5213 unique artists collected.
# ✅ pop (G*): 5245 unique artists collected.
# ✅ pop (G*): 5279 unique artists collected.
# ✅ pop (G*): 5308 unique artists collected.
# ✅ pop (G*): 5336 unique artists collected.
# ✅ pop (G*): 5372 unique artists collected.
# ✅ pop (G*): 5408 unique artists collected.
# ✅ pop (G*): 5441 unique artists collected.
# ✅ pop (G*): 5475 unique artists collected.
# ✅ pop (G*): 5513 unique artists collected.
# ✅ pop (G*): 5545 unique artists collected.
# ✅ pop (G*): 5590 unique artists collected.
# ✅ pop (G*): 5631 unique artists collected.
# ✅ pop (G*): 5674 unique artists collected.
# ✅ pop (G*): 5721 unique artists collected.
# ✅ pop (G*): 5771 unique artists collected.
# ✅ pop (G*): 5811 unique artists collected.
# ✅ pop (G*): 5858 unique artists collected.
# ✅ pop (G*): 5903 unique artists collected.
# ✅ pop (G*): 5948 unique artists collected.
# ✅ pop (H*): 5983 unique artists collected.
# ✅ pop (H*): 6019 unique artists collected.
# ✅ pop (H*): 6052 unique artists collected.
# ✅ pop (H*): 6088 unique artists collected.
# ✅ pop (H*): 6123 unique artists collected.
# ✅ pop (H*): 6154 unique artists collected.
# ✅ pop (H*): 6184 unique artists collected.
# ✅ pop (H*): 6222 unique artists collected.
# ✅ pop (H*): 6264 unique artists collected.
# ✅ pop (H*): 6301 unique artists collected.
# ✅ pop (H*): 6339 unique artists collected.
# ✅ pop (H*): 6380 unique artists collected.
# ✅ pop (H*): 6422 unique artists collected.
# ✅ pop (H*): 6464 unique artists collected.
# ✅ pop (H*): 6513 unique artists collected.
# ✅ pop (H*): 6558 unique artists collected.
# ✅ pop (H*): 6605 unique artists collected.
# ✅ pop (H*): 6645 unique artists collected.
# ✅ pop (H*): 6692 unique artists collected.
# ✅ pop (H*): 6732 unique artists collected.
# ✅ pop (I*): 6760 unique artists collected.
# ✅ pop (I*): 6787 unique artists collected.
# ✅ pop (I*): 6819 unique artists collected.
# ✅ pop (I*): 6854 unique artists collected.
# ✅ pop (I*): 6891 unique artists collected.
# ✅ pop (I*): 6929 unique artists collected.
# ✅ pop (I*): 6971 unique artists collected.
# ✅ pop (I*): 7011 unique artists collected.
# ✅ pop (I*): 7056 unique artists collected.
# ✅ pop (I*): 7105 unique artists collected.
# ✅ pop (I*): 7152 unique artists collected.
# ✅ pop (I*): 7202 unique artists collected.
# ✅ pop (I*): 7252 unique artists collected.
# ✅ pop (I*): 7302 unique artists collected.
# ✅ pop (I*): 7352 unique artists collected.
# ✅ pop (I*): 7402 unique artists collected.
# ✅ pop (I*): 7452 unique artists collected.
# ✅ pop (I*): 7502 unique artists collected.
# ✅ pop (I*): 7552 unique artists collected.
# ✅ pop (I*): 7602 unique artists collected.
# ✅ pop (J*): 7631 unique artists collected.
# ✅ pop (J*): 7651 unique artists collected.
# ✅ pop (J*): 7680 unique artists collected.
# ✅ pop (J*): 7707 unique artists collected.
# ✅ pop (J*): 7736 unique artists collected.
# ✅ pop (J*): 7762 unique artists collected.
# ✅ pop (J*): 7785 unique artists collected.
# ✅ pop (J*): 7802 unique artists collected.
# ✅ pop (J*): 7827 unique artists collected.
# ✅ pop (J*): 7853 unique artists collected.
# ✅ pop (J*): 7880 unique artists collected.
# ✅ pop (J*): 7904 unique artists collected.
# ✅ pop (J*): 7930 unique artists collected.
# ✅ pop (J*): 7951 unique artists collected.
# ✅ pop (J*): 7982 unique artists collected.
# ✅ pop (J*): 8019 unique artists collected.
# ✅ pop (J*): 8046 unique artists collected.
# ✅ pop (J*): 8076 unique artists collected.
# ✅ pop (J*): 8108 unique artists collected.
# ✅ pop (J*): 8142 unique artists collected.
# ✅ pop (K*): 8173 unique artists collected.
# ✅ pop (K*): 8201 unique artists collected.
# ✅ pop (K*): 8234 unique artists collected.
# ✅ pop (K*): 8265 unique artists collected.
# ✅ pop (K*): 8294 unique artists collected.
# ✅ pop (K*): 8329 unique artists collected.
# ✅ pop (K*): 8366 unique artists collected.
# ✅ pop (K*): 8396 unique artists collected.
# ✅ pop (K*): 8427 unique artists collected.
# ✅ pop (K*): 8459 unique artists collected.
# ✅ pop (K*): 8485 unique artists collected.
# ✅ pop (K*): 8517 unique artists collected.
# ✅ pop (K*): 8552 unique artists collected.
# ✅ pop (K*): 8584 unique artists collected.
# ✅ pop (K*): 8621 unique artists collected.
# ✅ pop (K*): 8659 unique artists collected.
# ✅ pop (K*): 8700 unique artists collected.
# ✅ pop (K*): 8740 unique artists collected.
# ✅ pop (K*): 8782 unique artists collected.
# ✅ pop (K*): 8823 unique artists collected.
# ✅ pop (L*): 8847 unique artists collected.
# ✅ pop (L*): 8874 unique artists collected.
# ✅ pop (L*): 8899 unique artists collected.
# ✅ pop (L*): 8924 unique artists collected.
# ✅ pop (L*): 8948 unique artists collected.
# ✅ pop (L*): 8973 unique artists collected.
# ✅ pop (L*): 8994 unique artists collected.
# ✅ pop (L*): 9017 unique artists collected.
# ✅ pop (L*): 9044 unique artists collected.
# ✅ pop (L*): 9066 unique artists collected.
# ✅ pop (L*): 9089 unique artists collected.
# ✅ pop (L*): 9112 unique artists collected.
# ✅ pop (L*): 9137 unique artists collected.
# ✅ pop (L*): 9165 unique artists collected.
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: None
# ✅ pop (L*): 9189 unique artists collected.
# ✅ pop (L*): 9216 unique artists collected.
# ✅ pop (L*): 9243 unique artists collected.
# ✅ pop (L*): 9276 unique artists collected.
# ✅ pop (L*): 9310 unique artists collected.
# ✅ pop (L*): 9347 unique artists collected.
# ✅ pop (M*): 9375 unique artists collected.
# ✅ pop (M*): 9394 unique artists collected.
# ✅ pop (M*): 9428 unique artists collected.
# ✅ pop (M*): 9452 unique artists collected.
# ✅ pop (M*): 9481 unique artists collected.
# ✅ pop (M*): 9512 unique artists collected.
# ✅ pop (M*): 9529 unique artists collected.
# ✅ pop (M*): 9553 unique artists collected.
# ✅ pop (M*): 9576 unique artists collected.
# ✅ pop (M*): 9600 unique artists collected.
# ✅ pop (M*): 9623 unique artists collected.
# ✅ pop (M*): 9651 unique artists collected.
# ✅ pop (M*): 9676 unique artists collected.
# ✅ pop (M*): 9705 unique artists collected.
# ✅ pop (M*): 9726 unique artists collected.
# ✅ pop (M*): 9757 unique artists collected.
# ✅ pop (M*): 9785 unique artists collected.
# ✅ pop (M*): 9809 unique artists collected.
# ✅ pop (M*): 9836 unique artists collected.
# ✅ pop (M*): 9855 unique artists collected.
# ✅ pop (N*): 9875 unique artists collected.
# ✅ pop (N*): 9891 unique artists collected.
# ✅ pop (N*): 9906 unique artists collected.
# ✅ pop (N*): 9923 unique artists collected.
# ✅ pop (N*): 9941 unique artists collected.
# ✅ pop (N*): 9957 unique artists collected.
# ✅ pop (N*): 9972 unique artists collected.
# ✅ pop (N*): 9992 unique artists collected.
# ✅ pop (N*): 10004 unique artists collected.
# ✅ pop (N*): 10019 unique artists collected.
# ✅ pop (N*): 10042 unique artists collected.
# ✅ pop (N*): 10066 unique artists collected.
# ✅ pop (N*): 10090 unique artists collected.
# ✅ pop (N*): 10124 unique artists collected.
# ✅ pop (N*): 10151 unique artists collected.
# ✅ pop (N*): 10182 unique artists collected.
# ✅ pop (N*): 10214 unique artists collected.
# ✅ pop (N*): 10245 unique artists collected.
# ✅ pop (N*): 10278 unique artists collected.
# ✅ pop (N*): 10311 unique artists collected.
# ✅ pop (O*): 10328 unique artists collected.
# ✅ pop (O*): 10337 unique artists collected.
# ✅ pop (O*): 10346 unique artists collected.
# ✅ pop (O*): 10360 unique artists collected.
# ✅ pop (O*): 10373 unique artists collected.
# ✅ pop (O*): 10389 unique artists collected.
# ✅ pop (O*): 10397 unique artists collected.
# ✅ pop (O*): 10410 unique artists collected.
# ✅ pop (O*): 10431 unique artists collected.
# ✅ pop (O*): 10452 unique artists collected.
# ✅ pop (O*): 10479 unique artists collected.
# ✅ pop (O*): 10505 unique artists collected.
# ✅ pop (O*): 10536 unique artists collected.
# ✅ pop (O*): 10561 unique artists collected.
# ✅ pop (O*): 10596 unique artists collected.
# ✅ pop (O*): 10635 unique artists collected.
# ✅ pop (O*): 10682 unique artists collected.
# ✅ pop (O*): 10726 unique artists collected.
# ✅ pop (O*): 10775 unique artists collected.
# ✅ pop (O*): 10825 unique artists collected.
# ✅ pop (P*): 10843 unique artists collected.
# ✅ pop (P*): 10857 unique artists collected.
# ✅ pop (P*): 10871 unique artists collected.
# ✅ pop (P*): 10882 unique artists collected.
# ✅ pop (P*): 10897 unique artists collected.
# ✅ pop (P*): 10913 unique artists collected.
# ✅ pop (P*): 10929 unique artists collected.
# ✅ pop (P*): 10947 unique artists collected.
# ✅ pop (P*): 10959 unique artists collected.
# ✅ pop (P*): 10985 unique artists collected.
# ✅ pop (P*): 11003 unique artists collected.
# ✅ pop (P*): 11018 unique artists collected.
# ✅ pop (P*): 11035 unique artists collected.
# ✅ pop (P*): 11060 unique artists collected.
# ✅ pop (P*): 11078 unique artists collected.
# ✅ pop (P*): 11102 unique artists collected.
# ✅ pop (P*): 11120 unique artists collected.
# ✅ pop (P*): 11141 unique artists collected.
# ✅ pop (P*): 11165 unique artists collected.
# ✅ pop (P*): 11197 unique artists collected.
# ✅ pop (Q*): 11217 unique artists collected.
# ✅ pop (Q*): 11257 unique artists collected.
# ✅ pop (Q*): 11304 unique artists collected.
# ✅ pop (Q*): 11353 unique artists collected.
# ✅ pop (Q*): 11403 unique artists collected.
# ✅ pop (Q*): 11453 unique artists collected.
# ✅ pop (Q*): 11457 unique artists collected.
# ✅ pop (R*): 11472 unique artists collected.
# ✅ pop (R*): 11486 unique artists collected.
# ✅ pop (R*): 11505 unique artists collected.
# ✅ pop (R*): 11523 unique artists collected.
# ✅ pop (R*): 11540 unique artists collected.
# ✅ pop (R*): 11564 unique artists collected.
# ✅ pop (R*): 11579 unique artists collected.
# ✅ pop (R*): 11600 unique artists collected.
# ✅ pop (R*): 11618 unique artists collected.
# ✅ pop (R*): 11637 unique artists collected.
# ✅ pop (R*): 11655 unique artists collected.
# ✅ pop (R*): 11680 unique artists collected.
# ✅ pop (R*): 11704 unique artists collected.
# ✅ pop (R*): 11734 unique artists collected.
# ✅ pop (R*): 11764 unique artists collected.
# ✅ pop (R*): 11796 unique artists collected.
# ✅ pop (R*): 11824 unique artists collected.
# ✅ pop (R*): 11859 unique artists collected.
# ✅ pop (R*): 11888 unique artists collected.
# ✅ pop (R*): 11926 unique artists collected.
# ✅ pop (S*): 11945 unique artists collected.
# ✅ pop (S*): 11960 unique artists collected.
# ✅ pop (S*): 11975 unique artists collected.
# ✅ pop (S*): 11989 unique artists collected.
# ✅ pop (S*): 12001 unique artists collected.
# ✅ pop (S*): 12013 unique artists collected.
# ✅ pop (S*): 12032 unique artists collected.
# ✅ pop (S*): 12050 unique artists collected.
# ✅ pop (S*): 12071 unique artists collected.
# ✅ pop (S*): 12089 unique artists collected.
# ✅ pop (S*): 12111 unique artists collected.
# ✅ pop (S*): 12128 unique artists collected.
# ✅ pop (S*): 12143 unique artists collected.
# ✅ pop (S*): 12156 unique artists collected.
# ✅ pop (S*): 12180 unique artists collected.
# ✅ pop (S*): 12199 unique artists collected.
# ✅ pop (S*): 12220 unique artists collected.
# ✅ pop (S*): 12236 unique artists collected.
# ✅ pop (S*): 12257 unique artists collected.
# ✅ pop (S*): 12280 unique artists collected.
# ✅ pop (T*): 12292 unique artists collected.
# ✅ pop (T*): 12300 unique artists collected.
# ✅ pop (T*): 12311 unique artists collected.
# ✅ pop (T*): 12324 unique artists collected.
# ✅ pop (T*): 12340 unique artists collected.
# ✅ pop (T*): 12353 unique artists collected.
# ✅ pop (T*): 12366 unique artists collected.
# ✅ pop (T*): 12373 unique artists collected.
# ✅ pop (T*): 12384 unique artists collected.
# ✅ pop (T*): 12397 unique artists collected.
# ✅ pop (T*): 12409 unique artists collected.
# ✅ pop (T*): 12422 unique artists collected.
# ✅ pop (T*): 12431 unique artists collected.
# ✅ pop (T*): 12436 unique artists collected.
# ✅ pop (T*): 12449 unique artists collected.
# ✅ pop (T*): 12464 unique artists collected.
# ✅ pop (T*): 12482 unique artists collected.
# ✅ pop (T*): 12498 unique artists collected.
# ✅ pop (T*): 12520 unique artists collected.
# ✅ pop (T*): 12541 unique artists collected.
# ✅ pop (U*): 12544 unique artists collected.
# ✅ pop (U*): 12550 unique artists collected.
# ✅ pop (U*): 12553 unique artists collected.
# ✅ pop (U*): 12561 unique artists collected.
# ✅ pop (U*): 12572 unique artists collected.
# ✅ pop (U*): 12585 unique artists collected.
# ✅ pop (U*): 12603 unique artists collected.
# ✅ pop (U*): 12627 unique artists collected.
# ✅ pop (U*): 12654 unique artists collected.
# ✅ pop (U*): 12679 unique artists collected.
# ✅ pop (U*): 12726 unique artists collected.
# ✅ pop (U*): 12773 unique artists collected.
# ✅ pop (U*): 12823 unique artists collected.
# ✅ pop (U*): 12871 unique artists collected.
# ✅ pop (U*): 12920 unique artists collected.
# ✅ pop (U*): 12970 unique artists collected.
# ✅ pop (U*): 13018 unique artists collected.
# ✅ pop (U*): 13067 unique artists collected.
# ✅ pop (U*): 13117 unique artists collected.
# ✅ pop (U*): 13166 unique artists collected.
# ✅ pop (V*): 13174 unique artists collected.
# ✅ pop (V*): 13186 unique artists collected.
# ✅ pop (V*): 13198 unique artists collected.
# ✅ pop (V*): 13212 unique artists collected.
# ✅ pop (V*): 13228 unique artists collected.
# ✅ pop (V*): 13247 unique artists collected.
# ✅ pop (V*): 13276 unique artists collected.
# ✅ pop (V*): 13303 unique artists collected.
# ✅ pop (V*): 13339 unique artists collected.
# ✅ pop (V*): 13379 unique artists collected.
# ✅ pop (V*): 13419 unique artists collected.
# ✅ pop (V*): 13465 unique artists collected.
# ✅ pop (V*): 13511 unique artists collected.
# ✅ pop (V*): 13553 unique artists collected.
# ✅ pop (V*): 13599 unique artists collected.
# ✅ pop (V*): 13645 unique artists collected.
# ✅ pop (V*): 13693 unique artists collected.
# ✅ pop (V*): 13741 unique artists collected.
# ✅ pop (V*): 13788 unique artists collected.
# ✅ pop (V*): 13833 unique artists collected.
# ✅ pop (W*): 13842 unique artists collected.
# ✅ pop (W*): 13854 unique artists collected.
# ✅ pop (W*): 13863 unique artists collected.
# ✅ pop (W*): 13876 unique artists collected.
# ✅ pop (W*): 13884 unique artists collected.
# ✅ pop (W*): 13894 unique artists collected.
# ✅ pop (W*): 13913 unique artists collected.
# ✅ pop (W*): 13929 unique artists collected.
# ✅ pop (W*): 13951 unique artists collected.
# ✅ pop (W*): 13980 unique artists collected.
# ✅ pop (W*): 14015 unique artists collected.
# ✅ pop (W*): 14057 unique artists collected.
# ✅ pop (W*): 14103 unique artists collected.
# ✅ pop (W*): 14145 unique artists collected.
# ✅ pop (W*): 14190 unique artists collected.
# ✅ pop (W*): 14237 unique artists collected.
# ✅ pop (W*): 14286 unique artists collected.
# ✅ pop (W*): 14334 unique artists collected.
# ✅ pop (W*): 14381 unique artists collected.
# ✅ pop (W*): 14426 unique artists collected.
# ✅ pop (X*): 14445 unique artists collected.
# ✅ pop (X*): 14483 unique artists collected.
# ✅ pop (X*): 14530 unique artists collected.
# ✅ pop (X*): 14580 unique artists collected.
# ✅ pop (X*): 14626 unique artists collected.
# ✅ pop (X*): 14639 unique artists collected.
# ✅ pop (Y*): 14649 unique artists collected.
# ✅ pop (Y*): 14660 unique artists collected.
# ✅ pop (Y*): 14666 unique artists collected.
# ✅ pop (Y*): 14668 unique artists collected.
# ✅ pop (Y*): 14681 unique artists collected.
# ✅ pop (Y*): 14687 unique artists collected.
# ✅ pop (Y*): 14702 unique artists collected.
# ✅ pop (Y*): 14718 unique artists collected.
# ✅ pop (Y*): 14735 unique artists collected.
# ✅ pop (Y*): 14753 unique artists collected.
# ✅ pop (Y*): 14776 unique artists collected.
# ✅ pop (Y*): 14799 unique artists collected.
# ✅ pop (Y*): 14821 unique artists collected.
# ⚠️ Error occurred at offset 650 for pop (Y*): HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=5)
# ✅ pop (Z*): 14838 unique artists collected.
# ✅ pop (Z*): 14858 unique artists collected.
# ✅ pop (Z*): 14879 unique artists collected.
# ✅ pop (Z*): 14912 unique artists collected.
# ✅ pop (Z*): 14947 unique artists collected.
# ✅ pop (Z*): 14994 unique artists collected.
# ✅ pop (Z*): 15040 unique artists collected.
# ✅ pop (Z*): 15087 unique artists collected.
# ✅ pop (Z*): 15134 unique artists collected.
# ✅ pop (Z*): 15179 unique artists collected.
# ✅ pop (Z*): 15223 unique artists collected.
# ✅ pop (Z*): 15269 unique artists collected.
# ✅ pop (Z*): 15315 unique artists collected.
# ✅ pop (Z*): 15363 unique artists collected.
# ✅ pop (Z*): 15409 unique artists collected.
# ✅ pop (Z*): 15459 unique artists collected.
# ✅ pop (Z*): 15509 unique artists collected.
# ✅ pop (Z*): 15558 unique artists collected.
# ✅ pop (Z*): 15590 unique artists collected.
# ✅ pop (Z*): 15619 unique artists collected.
# ✅ pop (0*): 15645 unique artists collected.
# ✅ pop (1*): 15651 unique artists collected.
# ✅ pop (1*): 15687 unique artists collected.
# ✅ pop (1*): 15728 unique artists collected.
# ✅ pop (1*): 15773 unique artists collected.
# ✅ pop (1*): 15799 unique artists collected.
# ✅ pop (2*): 15809 unique artists collected.
# ✅ pop (2*): 15851 unique artists collected.
# ✅ pop (2*): 15890 unique artists collected.
# ✅ pop (2*): 15935 unique artists collected.
# ✅ pop (2*): 15964 unique artists collected.
# ✅ pop (3*): 15988 unique artists collected.
# ✅ pop (3*): 16026 unique artists collected.
# ✅ pop (3*): 16056 unique artists collected.
# ✅ pop (4*): 16069 unique artists collected.
# ✅ pop (4*): 16113 unique artists collected.
# ✅ pop (4*): 16157 unique artists collected.
# ✅ pop (4*): 16158 unique artists collected.
# ✅ pop (5*): 16177 unique artists collected.
# ✅ pop (5*): 16207 unique artists collected.
# ✅ pop (6*): 16234 unique artists collected.
# ✅ pop (6*): 16241 unique artists collected.
# ✅ pop (7*): 16269 unique artists collected.
# ✅ pop (7*): 16290 unique artists collected.
# ✅ pop (8*): 16320 unique artists collected.
# ✅ pop (9*): 16354 unique artists collected.
# ✅ pop (9*): 16373 unique artists collected.
# 🔍 Searching for artists in the 'hip-hop' genre...
# ✅ hip-hop (A*): 16412 unique artists collected.
# ✅ hip-hop (A*): 16447 unique artists collected.
# ✅ hip-hop (A*): 16487 unique artists collected.
# ✅ hip-hop (A*): 16527 unique artists collected.
# ✅ hip-hop (A*): 16571 unique artists collected.
# ✅ hip-hop (A*): 16613 unique artists collected.
# ✅ hip-hop (A*): 16660 unique artists collected.
# ✅ hip-hop (A*): 16705 unique artists collected.
# ✅ hip-hop (A*): 16750 unique artists collected.
# ✅ hip-hop (A*): 16797 unique artists collected.
# ✅ hip-hop (A*): 16845 unique artists collected.
# ✅ hip-hop (A*): 16894 unique artists collected.
# ✅ hip-hop (A*): 16943 unique artists collected.
# ✅ hip-hop (A*): 16991 unique artists collected.
# ✅ hip-hop (A*): 17039 unique artists collected.
# ✅ hip-hop (A*): 17088 unique artists collected.
# ✅ hip-hop (A*): 17137 unique artists collected.
# ✅ hip-hop (A*): 17183 unique artists collected.
# ✅ hip-hop (A*): 17231 unique artists collected.
# ✅ hip-hop (A*): 17279 unique artists collected.
# ✅ hip-hop (B*): 17317 unique artists collected.
# ✅ hip-hop (B*): 17359 unique artists collected.
# ✅ hip-hop (B*): 17401 unique artists collected.
# ✅ hip-hop (B*): 17437 unique artists collected.
# ✅ hip-hop (B*): 17473 unique artists collected.
# ✅ hip-hop (B*): 17511 unique artists collected.
# ✅ hip-hop (B*): 17555 unique artists collected.
# ✅ hip-hop (B*): 17589 unique artists collected.
# ✅ hip-hop (B*): 17629 unique artists collected.
# ✅ hip-hop (B*): 17673 unique artists collected.
# ✅ hip-hop (B*): 17720 unique artists collected.
# ✅ hip-hop (B*): 17767 unique artists collected.
# ✅ hip-hop (B*): 17813 unique artists collected.
# ✅ hip-hop (B*): 17860 unique artists collected.
# ✅ hip-hop (B*): 17904 unique artists collected.
# ✅ hip-hop (B*): 17949 unique artists collected.
# ✅ hip-hop (B*): 17995 unique artists collected.
# ✅ hip-hop (B*): 18042 unique artists collected.
# ✅ hip-hop (B*): 18088 unique artists collected.
# ✅ hip-hop (B*): 18134 unique artists collected.
# ✅ hip-hop (C*): 18169 unique artists collected.
# ✅ hip-hop (C*): 18211 unique artists collected.
# ✅ hip-hop (C*): 18244 unique artists collected.
# ✅ hip-hop (C*): 18281 unique artists collected.
# ✅ hip-hop (C*): 18317 unique artists collected.
# ✅ hip-hop (C*): 18359 unique artists collected.
# ✅ hip-hop (C*): 18404 unique artists collected.
# ✅ hip-hop (C*): 18440 unique artists collected.
# ✅ hip-hop (C*): 18481 unique artists collected.
# ✅ hip-hop (C*): 18520 unique artists collected.
# ✅ hip-hop (C*): 18561 unique artists collected.
# ✅ hip-hop (C*): 18602 unique artists collected.
# ✅ hip-hop (C*): 18649 unique artists collected.
# ✅ hip-hop (C*): 18692 unique artists collected.
# ✅ hip-hop (C*): 18734 unique artists collected.
# ✅ hip-hop (C*): 18781 unique artists collected.
# ✅ hip-hop (C*): 18827 unique artists collected.
# ✅ hip-hop (C*): 18874 unique artists collected.
# ✅ hip-hop (C*): 18922 unique artists collected.
# ✅ hip-hop (C*): 18972 unique artists collected.
# ✅ hip-hop (D*): 19002 unique artists collected.
# ✅ hip-hop (D*): 19041 unique artists collected.
# ✅ hip-hop (D*): 19070 unique artists collected.
# ✅ hip-hop (D*): 19097 unique artists collected.
# ✅ hip-hop (D*): 19126 unique artists collected.
# ✅ hip-hop (D*): 19159 unique artists collected.
# ✅ hip-hop (D*): 19189 unique artists collected.
# ✅ hip-hop (D*): 19220 unique artists collected.
# ✅ hip-hop (D*): 19256 unique artists collected.
# ✅ hip-hop (D*): 19296 unique artists collected.
# ✅ hip-hop (D*): 19335 unique artists collected.
# ✅ hip-hop (D*): 19372 unique artists collected.
# ✅ hip-hop (D*): 19413 unique artists collected.
# ✅ hip-hop (D*): 19457 unique artists collected.
# ✅ hip-hop (D*): 19495 unique artists collected.
# ✅ hip-hop (D*): 19536 unique artists collected.
# ✅ hip-hop (D*): 19575 unique artists collected.
# ✅ hip-hop (D*): 19624 unique artists collected.
# ✅ hip-hop (D*): 19668 unique artists collected.
# ✅ hip-hop (D*): 19707 unique artists collected.
# ✅ hip-hop (E*): 19728 unique artists collected.
# ✅ hip-hop (E*): 19749 unique artists collected.
# ✅ hip-hop (E*): 19778 unique artists collected.
# ✅ hip-hop (E*): 19807 unique artists collected.
# ✅ hip-hop (E*): 19839 unique artists collected.
# ✅ hip-hop (E*): 19866 unique artists collected.
# ✅ hip-hop (E*): 19902 unique artists collected.
# ✅ hip-hop (E*): 19933 unique artists collected.
# ✅ hip-hop (E*): 19960 unique artists collected.
# ✅ hip-hop (E*): 19995 unique artists collected.
# ✅ hip-hop (E*): 20030 unique artists collected.
# ✅ hip-hop (E*): 20078 unique artists collected.
# ✅ hip-hop (E*): 20126 unique artists collected.
# ✅ hip-hop (E*): 20176 unique artists collected.
# ✅ hip-hop (E*): 20224 unique artists collected.
# ✅ hip-hop (E*): 20273 unique artists collected.
# ✅ hip-hop (E*): 20321 unique artists collected.
# ✅ hip-hop (E*): 20371 unique artists collected.
# ✅ hip-hop (E*): 20409 unique artists collected.
# ✅ hip-hop (E*): 20458 unique artists collected.
# ✅ hip-hop (F*): 20481 unique artists collected.
# ✅ hip-hop (F*): 20510 unique artists collected.
# ✅ hip-hop (F*): 20542 unique artists collected.
# ✅ hip-hop (F*): 20573 unique artists collected.
# ✅ hip-hop (F*): 20604 unique artists collected.
# ✅ hip-hop (F*): 20635 unique artists collected.
# ✅ hip-hop (F*): 20668 unique artists collected.
# ✅ hip-hop (F*): 20696 unique artists collected.
# ✅ hip-hop (F*): 20734 unique artists collected.
# ✅ hip-hop (F*): 20769 unique artists collected.
# ✅ hip-hop (F*): 20809 unique artists collected.
# ✅ hip-hop (F*): 20852 unique artists collected.
# ✅ hip-hop (F*): 20897 unique artists collected.
# ✅ hip-hop (F*): 20941 unique artists collected.
# ✅ hip-hop (F*): 20985 unique artists collected.
# ✅ hip-hop (F*): 21031 unique artists collected.
# ✅ hip-hop (F*): 21075 unique artists collected.
# ✅ hip-hop (F*): 21123 unique artists collected.
# ✅ hip-hop (F*): 21166 unique artists collected.
# ✅ hip-hop (F*): 21216 unique artists collected.
# ✅ hip-hop (G*): 21240 unique artists collected.
# ✅ hip-hop (G*): 21276 unique artists collected.
# ✅ hip-hop (G*): 21305 unique artists collected.
# ✅ hip-hop (G*): 21335 unique artists collected.
# ✅ hip-hop (G*): 21363 unique artists collected.
# ✅ hip-hop (G*): 21391 unique artists collected.
# ✅ hip-hop (G*): 21428 unique artists collected.
# ✅ hip-hop (G*): 21463 unique artists collected.
# ✅ hip-hop (G*): 21501 unique artists collected.
# ✅ hip-hop (G*): 21538 unique artists collected.
# ✅ hip-hop (G*): 21571 unique artists collected.
# ✅ hip-hop (G*): 21611 unique artists collected.
# ✅ hip-hop (G*): 21654 unique artists collected.
# ✅ hip-hop (G*): 21699 unique artists collected.
# ✅ hip-hop (G*): 21745 unique artists collected.
# ✅ hip-hop (G*): 21793 unique artists collected.
# ✅ hip-hop (G*): 21841 unique artists collected.
# ✅ hip-hop (G*): 21888 unique artists collected.
# ✅ hip-hop (G*): 21933 unique artists collected.
# ✅ hip-hop (G*): 21979 unique artists collected.
# ✅ hip-hop (H*): 22005 unique artists collected.
# ✅ hip-hop (H*): 22031 unique artists collected.
# ✅ hip-hop (H*): 22064 unique artists collected.
# ✅ hip-hop (H*): 22093 unique artists collected.
# ✅ hip-hop (H*): 22128 unique artists collected.
# ✅ hip-hop (H*): 22165 unique artists collected.
# ✅ hip-hop (H*): 22198 unique artists collected.
# ✅ hip-hop (H*): 22239 unique artists collected.
# ✅ hip-hop (H*): 22278 unique artists collected.
# ✅ hip-hop (H*): 22323 unique artists collected.
# ✅ hip-hop (H*): 22369 unique artists collected.
# ✅ hip-hop (H*): 22412 unique artists collected.
# ✅ hip-hop (H*): 22457 unique artists collected.
# ✅ hip-hop (H*): 22504 unique artists collected.
# ✅ hip-hop (H*): 22549 unique artists collected.
# ✅ hip-hop (H*): 22595 unique artists collected.
# ✅ hip-hop (H*): 22641 unique artists collected.
# ✅ hip-hop (H*): 22687 unique artists collected.
# ✅ hip-hop (H*): 22710 unique artists collected.
# ✅ hip-hop (H*): 22740 unique artists collected.
# ✅ hip-hop (I*): 22771 unique artists collected.
# ✅ hip-hop (I*): 22794 unique artists collected.
# ✅ hip-hop (I*): 22829 unique artists collected.
# ✅ hip-hop (I*): 22856 unique artists collected.
# ✅ hip-hop (I*): 22891 unique artists collected.
# ✅ hip-hop (I*): 22927 unique artists collected.
# ✅ hip-hop (I*): 22961 unique artists collected.
# ✅ hip-hop (I*): 23007 unique artists collected.
# ✅ hip-hop (I*): 23054 unique artists collected.
# ✅ hip-hop (I*): 23101 unique artists collected.
# ✅ hip-hop (I*): 23146 unique artists collected.
# ✅ hip-hop (I*): 23192 unique artists collected.
# ✅ hip-hop (I*): 23236 unique artists collected.
# ✅ hip-hop (I*): 23277 unique artists collected.
# ✅ hip-hop (J*): 23298 unique artists collected.
# ✅ hip-hop (J*): 23317 unique artists collected.
# ✅ hip-hop (J*): 23340 unique artists collected.
# ✅ hip-hop (J*): 23366 unique artists collected.
# ✅ hip-hop (J*): 23392 unique artists collected.
# ✅ hip-hop (J*): 23417 unique artists collected.
# ✅ hip-hop (J*): 23449 unique artists collected.
# ✅ hip-hop (J*): 23486 unique artists collected.
# ✅ hip-hop (J*): 23516 unique artists collected.
# ✅ hip-hop (J*): 23548 unique artists collected.
# ✅ hip-hop (J*): 23573 unique artists collected.
# ✅ hip-hop (J*): 23608 unique artists collected.
# ✅ hip-hop (J*): 23640 unique artists collected.
# ✅ hip-hop (J*): 23675 unique artists collected.
# ✅ hip-hop (J*): 23709 unique artists collected.
# ✅ hip-hop (J*): 23746 unique artists collected.
# ✅ hip-hop (J*): 23781 unique artists collected.
# ✅ hip-hop (J*): 23817 unique artists collected.
# ✅ hip-hop (J*): 23851 unique artists collected.
# ✅ hip-hop (J*): 23891 unique artists collected.
# ✅ hip-hop (K*): 23911 unique artists collected.
# ✅ hip-hop (K*): 23932 unique artists collected.
# ✅ hip-hop (K*): 23964 unique artists collected.
# ✅ hip-hop (K*): 23996 unique artists collected.
# ✅ hip-hop (K*): 24024 unique artists collected.
# ✅ hip-hop (K*): 24048 unique artists collected.
# ✅ hip-hop (K*): 24077 unique artists collected.
# ✅ hip-hop (K*): 24102 unique artists collected.
# ✅ hip-hop (K*): 24130 unique artists collected.
# ✅ hip-hop (K*): 24166 unique artists collected.
# ✅ hip-hop (K*): 24195 unique artists collected.
# ✅ hip-hop (K*): 24226 unique artists collected.
# ✅ hip-hop (K*): 24261 unique artists collected.
# ✅ hip-hop (K*): 24291 unique artists collected.
# ✅ hip-hop (K*): 24321 unique artists collected.
# ✅ hip-hop (K*): 24353 unique artists collected.
# ✅ hip-hop (K*): 24389 unique artists collected.
# ✅ hip-hop (K*): 24430 unique artists collected.
# ✅ hip-hop (K*): 24470 unique artists collected.
# ✅ hip-hop (K*): 24511 unique artists collected.
# ✅ hip-hop (L*): 24531 unique artists collected.
# ✅ hip-hop (L*): 24556 unique artists collected.
# ✅ hip-hop (L*): 24572 unique artists collected.
# ✅ hip-hop (L*): 24588 unique artists collected.
# ✅ hip-hop (L*): 24615 unique artists collected.
# ✅ hip-hop (L*): 24639 unique artists collected.
# ✅ hip-hop (L*): 24664 unique artists collected.
# ✅ hip-hop (L*): 24688 unique artists collected.
# ✅ hip-hop (L*): 24713 unique artists collected.
# ✅ hip-hop (L*): 24742 unique artists collected.
# ✅ hip-hop (L*): 24767 unique artists collected.
# ✅ hip-hop (L*): 24797 unique artists collected.
# ✅ hip-hop (L*): 24824 unique artists collected.
# ✅ hip-hop (L*): 24851 unique artists collected.
# ✅ hip-hop (L*): 24880 unique artists collected.
# ✅ hip-hop (L*): 24914 unique artists collected.
# ✅ hip-hop (L*): 24938 unique artists collected.
# ✅ hip-hop (L*): 24962 unique artists collected.
# ✅ hip-hop (L*): 24993 unique artists collected.
# ✅ hip-hop (L*): 25034 unique artists collected.
# ✅ hip-hop (M*): 25047 unique artists collected.
# ✅ hip-hop (M*): 25071 unique artists collected.
# ✅ hip-hop (M*): 25093 unique artists collected.
# ✅ hip-hop (M*): 25113 unique artists collected.
# ✅ hip-hop (M*): 25140 unique artists collected.
# ✅ hip-hop (M*): 25161 unique artists collected.
# ✅ hip-hop (M*): 25187 unique artists collected.
# ✅ hip-hop (M*): 25214 unique artists collected.
# ✅ hip-hop (M*): 25240 unique artists collected.
# ✅ hip-hop (M*): 25273 unique artists collected.
# ✅ hip-hop (M*): 25306 unique artists collected.
# ✅ hip-hop (M*): 25340 unique artists collected.
# ✅ hip-hop (M*): 25366 unique artists collected.
# ✅ hip-hop (M*): 25395 unique artists collected.
# ✅ hip-hop (M*): 25424 unique artists collected.
# ✅ hip-hop (M*): 25458 unique artists collected.
# ✅ hip-hop (M*): 25484 unique artists collected.
# ✅ hip-hop (M*): 25514 unique artists collected.
# ✅ hip-hop (M*): 25542 unique artists collected.
# ✅ hip-hop (M*): 25571 unique artists collected.
# ✅ hip-hop (N*): 25589 unique artists collected.
# ✅ hip-hop (N*): 25604 unique artists collected.
# ✅ hip-hop (N*): 25619 unique artists collected.
# ✅ hip-hop (N*): 25643 unique artists collected.
# ✅ hip-hop (N*): 25660 unique artists collected.
# ✅ hip-hop (N*): 25684 unique artists collected.
# ✅ hip-hop (N*): 25710 unique artists collected.
# ✅ hip-hop (N*): 25737 unique artists collected.
# ✅ hip-hop (N*): 25759 unique artists collected.
# ✅ hip-hop (N*): 25780 unique artists collected.
# ✅ hip-hop (N*): 25802 unique artists collected.
# ✅ hip-hop (N*): 25835 unique artists collected.
# ✅ hip-hop (N*): 25860 unique artists collected.
# ✅ hip-hop (N*): 25892 unique artists collected.
# ✅ hip-hop (N*): 25926 unique artists collected.
# ✅ hip-hop (N*): 25956 unique artists collected.
# ✅ hip-hop (N*): 25989 unique artists collected.
# ✅ hip-hop (N*): 26018 unique artists collected.
# ✅ hip-hop (N*): 26054 unique artists collected.
# ✅ hip-hop (N*): 26085 unique artists collected.
# ✅ hip-hop (O*): 26097 unique artists collected.
# ✅ hip-hop (O*): 26115 unique artists collected.
# ✅ hip-hop (O*): 26134 unique artists collected.
# ✅ hip-hop (O*): 26149 unique artists collected.
# ✅ hip-hop (O*): 26166 unique artists collected.
# ✅ hip-hop (O*): 26188 unique artists collected.
# ✅ hip-hop (O*): 26202 unique artists collected.
# ✅ hip-hop (O*): 26220 unique artists collected.
# ✅ hip-hop (O*): 26235 unique artists collected.
# ✅ hip-hop (O*): 26259 unique artists collected.
# ✅ hip-hop (O*): 26290 unique artists collected.
# ✅ hip-hop (O*): 26319 unique artists collected.
# ✅ hip-hop (O*): 26352 unique artists collected.
# ✅ hip-hop (O*): 26381 unique artists collected.
# ✅ hip-hop (O*): 26408 unique artists collected.
# ✅ hip-hop (O*): 26442 unique artists collected.
# ✅ hip-hop (O*): 26475 unique artists collected.
# ✅ hip-hop (O*): 26510 unique artists collected.
# ✅ hip-hop (O*): 26545 unique artists collected.
# ✅ hip-hop (O*): 26582 unique artists collected.
# ✅ hip-hop (P*): 26600 unique artists collected.
# ✅ hip-hop (P*): 26618 unique artists collected.
# ✅ hip-hop (P*): 26633 unique artists collected.
# ✅ hip-hop (P*): 26653 unique artists collected.
# ✅ hip-hop (P*): 26670 unique artists collected.
# ✅ hip-hop (P*): 26693 unique artists collected.
# ✅ hip-hop (P*): 26713 unique artists collected.
# ✅ hip-hop (P*): 26732 unique artists collected.
# ✅ hip-hop (P*): 26753 unique artists collected.
# ✅ hip-hop (P*): 26776 unique artists collected.
# ✅ hip-hop (P*): 26802 unique artists collected.
# ✅ hip-hop (P*): 26825 unique artists collected.
# ✅ hip-hop (P*): 26849 unique artists collected.
# ✅ hip-hop (P*): 26873 unique artists collected.
# ✅ hip-hop (P*): 26895 unique artists collected.
# ✅ hip-hop (P*): 26922 unique artists collected.
# ✅ hip-hop (P*): 26949 unique artists collected.
# ✅ hip-hop (P*): 26977 unique artists collected.
# ✅ hip-hop (P*): 27011 unique artists collected.
# ✅ hip-hop (P*): 27046 unique artists collected.
# ✅ hip-hop (Q*): 27069 unique artists collected.
# ✅ hip-hop (Q*): 27102 unique artists collected.
# ✅ hip-hop (Q*): 27143 unique artists collected.
# ✅ hip-hop (Q*): 27145 unique artists collected.
# ✅ hip-hop (R*): 27159 unique artists collected.
# ✅ hip-hop (R*): 27175 unique artists collected.
# ✅ hip-hop (R*): 27188 unique artists collected.
# ✅ hip-hop (R*): 27203 unique artists collected.
# ✅ hip-hop (R*): 27223 unique artists collected.
# ✅ hip-hop (R*): 27239 unique artists collected.
# ✅ hip-hop (R*): 27268 unique artists collected.
# ✅ hip-hop (R*): 27288 unique artists collected.
# ✅ hip-hop (R*): 27313 unique artists collected.
# ✅ hip-hop (R*): 27333 unique artists collected.
# ✅ hip-hop (R*): 27352 unique artists collected.
# ✅ hip-hop (R*): 27372 unique artists collected.
# ✅ hip-hop (R*): 27398 unique artists collected.
# ✅ hip-hop (R*): 27423 unique artists collected.
# ✅ hip-hop (R*): 27449 unique artists collected.
# ✅ hip-hop (R*): 27482 unique artists collected.
# ✅ hip-hop (R*): 27515 unique artists collected.
# ✅ hip-hop (R*): 27550 unique artists collected.
# ✅ hip-hop (R*): 27587 unique artists collected.
# ✅ hip-hop (R*): 27626 unique artists collected.
# ✅ hip-hop (S*): 27635 unique artists collected.
# ✅ hip-hop (S*): 27649 unique artists collected.
# ✅ hip-hop (S*): 27665 unique artists collected.
# ✅ hip-hop (S*): 27681 unique artists collected.
# ✅ hip-hop (S*): 27703 unique artists collected.
# ✅ hip-hop (S*): 27722 unique artists collected.
# ✅ hip-hop (S*): 27743 unique artists collected.
# ✅ hip-hop (S*): 27764 unique artists collected.
# ✅ hip-hop (S*): 27779 unique artists collected.
# ✅ hip-hop (S*): 27802 unique artists collected.
# ✅ hip-hop (S*): 27823 unique artists collected.
# ✅ hip-hop (S*): 27844 unique artists collected.
# ✅ hip-hop (S*): 27867 unique artists collected.
# ✅ hip-hop (S*): 27889 unique artists collected.
# ✅ hip-hop (S*): 27914 unique artists collected.
# ✅ hip-hop (S*): 27937 unique artists collected.
# ✅ hip-hop (S*): 27960 unique artists collected.
# ✅ hip-hop (S*): 27984 unique artists collected.
# ✅ hip-hop (S*): 28005 unique artists collected.
# ✅ hip-hop (S*): 28029 unique artists collected.
# ✅ hip-hop (T*): 28036 unique artists collected.
# ✅ hip-hop (T*): 28041 unique artists collected.
# ✅ hip-hop (T*): 28056 unique artists collected.
# ✅ hip-hop (T*): 28071 unique artists collected.
# ✅ hip-hop (T*): 28078 unique artists collected.
# ✅ hip-hop (T*): 28092 unique artists collected.
# ✅ hip-hop (T*): 28109 unique artists collected.
# ✅ hip-hop (T*): 28128 unique artists collected.
# ✅ hip-hop (T*): 28140 unique artists collected.
# ✅ hip-hop (T*): 28155 unique artists collected.
# ✅ hip-hop (T*): 28166 unique artists collected.
# ✅ hip-hop (T*): 28184 unique artists collected.
# ✅ hip-hop (T*): 28198 unique artists collected.
# ✅ hip-hop (T*): 28216 unique artists collected.
# ✅ hip-hop (T*): 28238 unique artists collected.
# ✅ hip-hop (T*): 28260 unique artists collected.
# ✅ hip-hop (T*): 28278 unique artists collected.
# ✅ hip-hop (T*): 28299 unique artists collected.
# ✅ hip-hop (T*): 28322 unique artists collected.
# ✅ hip-hop (T*): 28347 unique artists collected.
# ✅ hip-hop (U*): 28356 unique artists collected.
# ✅ hip-hop (U*): 28364 unique artists collected.
# ✅ hip-hop (U*): 28370 unique artists collected.
# ✅ hip-hop (U*): 28379 unique artists collected.
# ✅ hip-hop (U*): 28393 unique artists collected.
# ✅ hip-hop (U*): 28410 unique artists collected.
# ✅ hip-hop (U*): 28428 unique artists collected.
# ✅ hip-hop (U*): 28451 unique artists collected.
# ✅ hip-hop (U*): 28477 unique artists collected.
# ✅ hip-hop (U*): 28506 unique artists collected.
# ✅ hip-hop (U*): 28553 unique artists collected.
# ✅ hip-hop (U*): 28554 unique artists collected.
# ✅ hip-hop (V*): 28569 unique artists collected.
# ✅ hip-hop (V*): 28583 unique artists collected.
# ✅ hip-hop (V*): 28604 unique artists collected.
# ✅ hip-hop (V*): 28621 unique artists collected.
# ✅ hip-hop (V*): 28640 unique artists collected.
# ✅ hip-hop (V*): 28671 unique artists collected.
# ✅ hip-hop (V*): 28712 unique artists collected.
# ✅ hip-hop (V*): 28750 unique artists collected.
# ✅ hip-hop (V*): 28791 unique artists collected.
# ✅ hip-hop (V*): 28837 unique artists collected.
# ✅ hip-hop (V*): 28883 unique artists collected.
# ✅ hip-hop (V*): 28923 unique artists collected.
# ✅ hip-hop (V*): 28924 unique artists collected.
# ✅ hip-hop (W*): 28934 unique artists collected.
# ✅ hip-hop (W*): 28955 unique artists collected.
# ✅ hip-hop (W*): 28965 unique artists collected.
# ✅ hip-hop (W*): 28981 unique artists collected.
# ✅ hip-hop (W*): 28999 unique artists collected.
# ✅ hip-hop (W*): 29012 unique artists collected.
# ✅ hip-hop (W*): 29040 unique artists collected.
# ✅ hip-hop (W*): 29077 unique artists collected.
# ✅ hip-hop (W*): 29113 unique artists collected.
# ✅ hip-hop (W*): 29152 unique artists collected.
# ✅ hip-hop (W*): 29194 unique artists collected.
# ✅ hip-hop (W*): 29242 unique artists collected.
# ✅ hip-hop (W*): 29263 unique artists collected.
# ✅ hip-hop (W*): 29296 unique artists collected.
# ✅ hip-hop (X*): 29315 unique artists collected.
# ✅ hip-hop (X*): 29338 unique artists collected.
# ✅ hip-hop (X*): 29375 unique artists collected.
# ✅ hip-hop (X*): 29400 unique artists collected.
# ✅ hip-hop (Y*): 29404 unique artists collected.
# ✅ hip-hop (Y*): 29414 unique artists collected.
# ✅ hip-hop (Y*): 29420 unique artists collected.
# ✅ hip-hop (Y*): 29427 unique artists collected.
# ✅ hip-hop (Y*): 29435 unique artists collected.
# ✅ hip-hop (Y*): 29444 unique artists collected.
# ✅ hip-hop (Y*): 29463 unique artists collected.
# ✅ hip-hop (Y*): 29477 unique artists collected.
# ✅ hip-hop (Y*): 29496 unique artists collected.
# ✅ hip-hop (Y*): 29515 unique artists collected.
# ✅ hip-hop (Y*): 29543 unique artists collected.
# ✅ hip-hop (Y*): 29572 unique artists collected.
# ✅ hip-hop (Y*): 29604 unique artists collected.
# ✅ hip-hop (Y*): 29631 unique artists collected.
# ✅ hip-hop (Y*): 29662 unique artists collected.
# ✅ hip-hop (Y*): 29690 unique artists collected.
# ✅ hip-hop (Y*): 29709 unique artists collected.
# ✅ hip-hop (Y*): 29729 unique artists collected.
# ✅ hip-hop (Y*): 29752 unique artists collected.
# ✅ hip-hop (Y*): 29770 unique artists collected.
# ✅ hip-hop (Z*): 29787 unique artists collected.
# ✅ hip-hop (Z*): 29810 unique artists collected.
# ✅ hip-hop (Z*): 29832 unique artists collected.
# ✅ hip-hop (Z*): 29851 unique artists collected.
# ✅ hip-hop (Z*): 29884 unique artists collected.
# ✅ hip-hop (Z*): 29922 unique artists collected.
# ✅ hip-hop (Z*): 29963 unique artists collected.
# ✅ hip-hop (Z*): 30006 unique artists collected.
# ✅ hip-hop (Z*): 30009 unique artists collected.
# ✅ hip-hop (0*): 30023 unique artists collected.
# ✅ hip-hop (1*): 30026 unique artists collected.
# ✅ hip-hop (1*): 30033 unique artists collected.
# ✅ hip-hop (1*): 30056 unique artists collected.
# ✅ hip-hop (1*): 30093 unique artists collected.
# ✅ hip-hop (1*): 30109 unique artists collected.
# ✅ hip-hop (2*): 30110 unique artists collected.
# ✅ hip-hop (2*): 30112 unique artists collected.
# ✅ hip-hop (2*): 30130 unique artists collected.
# ✅ hip-hop (2*): 30158 unique artists collected.
# ✅ hip-hop (2*): 30166 unique artists collected.
# ✅ hip-hop (3*): 30169 unique artists collected.
# ✅ hip-hop (3*): 30178 unique artists collected.
# ✅ hip-hop (3*): 30208 unique artists collected.
# ✅ hip-hop (3*): 30244 unique artists collected.
# ✅ hip-hop (4*): 30245 unique artists collected.
# ✅ hip-hop (4*): 30266 unique artists collected.
# ✅ hip-hop (4*): 30301 unique artists collected.
# ✅ hip-hop (4*): 30305 unique artists collected.
# ✅ hip-hop (5*): 30309 unique artists collected.
# ✅ hip-hop (5*): 30329 unique artists collected.
# ✅ hip-hop (6*): 30344 unique artists collected.
# ✅ hip-hop (6*): 30353 unique artists collected.
# ✅ hip-hop (7*): 30361 unique artists collected.
# ✅ hip-hop (7*): 30386 unique artists collected.
# ✅ hip-hop (8*): 30399 unique artists collected.
# ✅ hip-hop (8*): 30412 unique artists collected.
# ✅ hip-hop (9*): 30421 unique artists collected.
# ✅ hip-hop (9*): 30454 unique artists collected.
# 🔍 Searching for artists in the 'rock' genre...
# ✅ rock (A*): 30483 unique artists collected.
# ✅ rock (A*): 30513 unique artists collected.
# ✅ rock (A*): 30542 unique artists collected.
# ✅ rock (A*): 30574 unique artists collected.
# ✅ rock (A*): 30610 unique artists collected.
# ✅ rock (A*): 30645 unique artists collected.
# ✅ rock (A*): 30682 unique artists collected.
# ✅ rock (A*): 30721 unique artists collected.
# ✅ rock (A*): 30760 unique artists collected.
# ✅ rock (A*): 30801 unique artists collected.
# ✅ rock (A*): 30846 unique artists collected.
# ✅ rock (A*): 30893 unique artists collected.
# ✅ rock (A*): 30934 unique artists collected.
# ✅ rock (A*): 30979 unique artists collected.
# ✅ rock (A*): 31024 unique artists collected.
# ✅ rock (A*): 31073 unique artists collected.
# ✅ rock (A*): 31121 unique artists collected.
# ✅ rock (A*): 31169 unique artists collected.
# ✅ rock (A*): 31219 unique artists collected.
# ✅ rock (A*): 31269 unique artists collected.
# ✅ rock (B*): 31298 unique artists collected.
# ✅ rock (B*): 31327 unique artists collected.
# ✅ rock (B*): 31352 unique artists collected.
# ✅ rock (B*): 31384 unique artists collected.
# ✅ rock (B*): 31413 unique artists collected.
# ✅ rock (B*): 31443 unique artists collected.
# ✅ rock (B*): 31472 unique artists collected.
# ✅ rock (B*): 31503 unique artists collected.
# ✅ rock (B*): 31536 unique artists collected.
# ✅ rock (B*): 31566 unique artists collected.
# ✅ rock (B*): 31599 unique artists collected.
# ✅ rock (B*): 31641 unique artists collected.
# ✅ rock (B*): 31679 unique artists collected.
# ✅ rock (B*): 31722 unique artists collected.
# ✅ rock (B*): 31761 unique artists collected.
# ✅ rock (B*): 31802 unique artists collected.
# ✅ rock (B*): 31841 unique artists collected.
# ✅ rock (B*): 31877 unique artists collected.
# ✅ rock (B*): 31921 unique artists collected.
# ✅ rock (B*): 31962 unique artists collected.
# ✅ rock (C*): 31990 unique artists collected.
# ✅ rock (C*): 32015 unique artists collected.
# ✅ rock (C*): 32043 unique artists collected.
# ✅ rock (C*): 32065 unique artists collected.
# ✅ rock (C*): 32093 unique artists collected.
# ✅ rock (C*): 32121 unique artists collected.
# ✅ rock (C*): 32155 unique artists collected.
# ✅ rock (C*): 32186 unique artists collected.
# ✅ rock (C*): 32218 unique artists collected.
# ✅ rock (C*): 32250 unique artists collected.
# ✅ rock (C*): 32283 unique artists collected.
# ✅ rock (C*): 32311 unique artists collected.
# ...
# ✅ metal (T*): 86784 unique artists collected.
# ✅ metal (T*): 86790 unique artists collected.
# ✅ metal (T*): 86804 unique artists collected.
# ✅ metal (T*): 86809 unique artists collected.
# ✅ metal (T*): 86821 unique artists collected.
# ✅ metal (T*): 86829 unique artists collected.
# ✅ metal (T*): 86835 unique artists collected.
# ✅ metal (T*): 86850 unique artists collected.
# ✅ metal (T*): 86864 unique artists collected.
# ✅ metal (T*): 86880 unique artists collected.
# ✅ metal (T*): 86892 unique artists collected.
# ✅ metal (U*): 86901 unique artists collected.
# ✅ metal (U*): 86921 unique artists collected.
# ✅ metal (U*): 86932 unique artists collected.
# ✅ metal (U*): 86959 unique artists collected.
# ✅ metal (U*): 86993 unique artists collected.
# ✅ metal (U*): 87034 unique artists collected.
# ✅ metal (U*): 87068 unique artists collected.
# ✅ metal (U*): 87098 unique artists collected.
# ✅ metal (U*): 87119 unique artists collected.
# ✅ metal (U*): 87144 unique artists collected.
# ✅ metal (U*): 87161 unique artists collected.
# ✅ metal (V*): 87179 unique artists collected.
# ✅ metal (V*): 87196 unique artists collected.
# ✅ metal (V*): 87216 unique artists collected.
# ✅ metal (V*): 87238 unique artists collected.
# ✅ metal (V*): 87258 unique artists collected.
# ✅ metal (V*): 87289 unique artists collected.
# ✅ metal (V*): 87314 unique artists collected.
# ✅ metal (V*): 87336 unique artists collected.
# ✅ metal (V*): 87367 unique artists collected.
# ✅ metal (V*): 87403 unique artists collected.
# ✅ metal (V*): 87433 unique artists collected.
# ✅ metal (V*): 87475 unique artists collected.
# ✅ metal (V*): 87518 unique artists collected.
# ✅ metal (V*): 87555 unique artists collected.
# ✅ metal (V*): 87577 unique artists collected.
# ✅ metal (V*): 87610 unique artists collected.
# ✅ metal (V*): 87642 unique artists collected.
# ✅ metal (V*): 87678 unique artists collected.
# ✅ metal (V*): 87714 unique artists collected.
# ✅ metal (V*): 87740 unique artists collected.
# ✅ metal (W*): 87744 unique artists collected.
# ✅ metal (W*): 87754 unique artists collected.
# ✅ metal (W*): 87770 unique artists collected.
# ✅ metal (W*): 87777 unique artists collected.
# ✅ metal (W*): 87796 unique artists collected.
# ✅ metal (W*): 87809 unique artists collected.
# ✅ metal (W*): 87826 unique artists collected.
# ✅ metal (W*): 87838 unique artists collected.
# ✅ metal (W*): 87851 unique artists collected.
# ✅ metal (W*): 87876 unique artists collected.
# ✅ metal (W*): 87910 unique artists collected.
# ✅ metal (W*): 87943 unique artists collected.
# ✅ metal (W*): 87970 unique artists collected.
# ✅ metal (W*): 88007 unique artists collected.
# ✅ metal (W*): 88045 unique artists collected.
# ✅ metal (W*): 88087 unique artists collected.
# ✅ metal (W*): 88131 unique artists collected.
# ✅ metal (W*): 88164 unique artists collected.
# ✅ metal (W*): 88205 unique artists collected.
# ✅ metal (W*): 88250 unique artists collected.
# ✅ metal (X*): 88283 unique artists collected.
# ✅ metal (X*): 88319 unique artists collected.
# ✅ metal (X*): 88333 unique artists collected.
# ✅ metal (Y*): 88336 unique artists collected.
# ✅ metal (Y*): 88347 unique artists collected.
# ✅ metal (Y*): 88372 unique artists collected.
# ✅ metal (Y*): 88403 unique artists collected.
# ✅ metal (Y*): 88427 unique artists collected.
# ✅ metal (Y*): 88443 unique artists collected.
# ✅ metal (Z*): 88463 unique artists collected.
# ✅ metal (Z*): 88498 unique artists collected.
# ✅ metal (Z*): 88538 unique artists collected.
# ✅ metal (Z*): 88584 unique artists collected.
# ✅ metal (Z*): 88593 unique artists collected.
# ✅ metal (0*): 88601 unique artists collected.
# ✅ metal (1*): 88618 unique artists collected.
# ✅ metal (1*): 88642 unique artists collected.
# ✅ metal (2*): 88665 unique artists collected.
# ✅ metal (3*): 88679 unique artists collected.
# ✅ metal (4*): 88689 unique artists collected.
# ✅ metal (5*): 88694 unique artists collected.
# ✅ metal (6*): 88708 unique artists collected.
# ✅ metal (7*): 88720 unique artists collected.
# ✅ metal (8*): 88725 unique artists collected.
# ✅ metal (9*): 88735 unique artists collected.
#
# 🎉 Total unique artists collected: 88735
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 5
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 3
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 5
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 5
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 5
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 5
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 5
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 5
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 5
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 5
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 5
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 5
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 3
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 5
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 5
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 4
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 5
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 1
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 85912
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-4ed263f9d37e> in <cell line: 0>()
#      51 for artist_id in artist_ids:
#      52     try:
# ---> 53         artist = sp.artist(artist_id)
#      54         artist_data.append({
#      55             "artist_id": artist_id,
#
# /usr/local/lib/python3.11/dist-packages/spotipy/client.py in artist(self, artist_id)
#     394
#     395         trid = self._get_id("artist", artist_id)
# --> 396         return self._get("artists/" + trid)
#     397
#     398     def artists(self, artists):
#
# /usr/local/lib/python3.11/dist-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     325             kwargs.update(args)
#     326
# --> 327         return self._internal_call("GET", url, payload, kwargs)
#     328
#     329     def _post(self, url, args=None, payload=None, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     268
#     269         try:
# --> 270             response = self._session.request(
#     271                 method, url, headers=headers, proxies=self.proxies,
#     272                 timeout=self.requests_timeout, **args
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.11/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     938
#     939             response.drain_conn()
# --> 940             retries.sleep(response)
#     941             log.debug("Retry: %s", url)
#     942             return self.urlopen(
#
# /usr/local/lib/python3.11/dist-packages/urllib3/util/retry.py in sleep(self, response)
#     357
#     358         if self.respect_retry_after_header and response:
# --> 359             slept = self.sleep_for_retry(response)
#     360             if slept:
#     361                 return
#
# /usr/local/lib/python3.11/dist-packages/urllib3/util/retry.py in sleep_for_retry(self, response)
#     336         retry_after = self.get_retry_after(response)
#     337         if retry_after:
# --> 338             time.sleep(retry_after)
#     339             return True
#     340
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(artist_ids)

# Save as CSV
df.to_csv("spotify_artists_testing.csv", index=False)

# %%
artist_df = pd.read_csv("spotify_artists_all.csv")

# Ensure the correct column name
print("Column Names in CSV:", artist_df.columns.tolist())

# Extract only artist IDs as a list
artist_ids = artist_df["0"].dropna().unique().tolist()

len(artist_ids)
# Out:
# Column Names in CSV: ['0']
# 88735

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time
import random
from tqdm import tqdm

# Spotify API credentials
client_id = "79ca2c801915487184f9d06993a76eb0"
client_secret = "63a590ad354c42f1ac766effc83f3076"

auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(auth_manager=auth_manager)

# Load dataset
df = pd.read_csv("/content/drive/MyDrive/Project 1/data.csv")

# Ensure correct column extraction
if "id" not in df.columns:
    print("❌ Column 'id' not found. Available columns:", df.columns)
    exit()

song_ids = df["id"].dropna().unique().tolist()

# Set initial delay parameters
MIN_SLEEP = 1.5  # Minimum wait time between requests
MAX_SLEEP = 5.0  # Maximum wait time if approaching rate limits
current_sleep = MIN_SLEEP  # Start with the minimum delay

# Function to handle rate limits
def handle_rate_limit(exception):
    global current_sleep
    if exception.http_status == 429:
        # Get Spotify's recommended wait time
        print(f"⚠️ Rate limit reached! Waiting for {'15'} seconds...")
        time.sleep(15)  # Wait before retrying
        current_sleep = min(MAX_SLEEP, current_sleep + 1)  # Increase delay to reduce future limits
    else:
        print(f"⚠️ API Error: {exception}")
        time.sleep(5)  # Short delay before retrying

# Fetch available markets for each song
song_market_data = []

print(f"🌍 Fetching available markets for {len(song_ids)} songs...")

for idx, song_id in enumerate(tqdm(song_ids, desc="Processing Songs", unit="song")):
    retries = 3  # Max retries per song
    while retries > 0:
        try:
            # Fetch track details
            track = sp.track(song_id)

            # Store available markets
            song_market_data.append({
                "song_id": song_id,
                "available_markets": ", ".join(track["available_markets"])
            })

            # Print progress every 100 songs
            if idx % 100 == 0:
                print(f"✅ [{idx+1}/{len(song_ids)}] Processed: {track['name']} ({len(track['available_markets'])} markets)")

            # Auto-save progress every 25 songs
            if idx % 25 == 0 and idx > 0:
                temp_df = pd.DataFrame(song_market_data)
                temp_df.to_csv("spotify_songs_markets_backup.csv", index=False)
                print(f"💾 Auto-saved progress at {idx} songs...")

            # Dynamically adjust sleep time
            time.sleep(current_sleep)  # Prevent rate limits by slowing down requests
            break  # Exit retry loop

        except spotipy.exceptions.SpotifyException as e:
            handle_rate_limit(e)
            retries -= 1
        except Exception as e:
            print(f"⚠️ General Error for {song_id}: {e}")
            retries -= 1
            time.sleep(5)

print(f"\n✅ Successfully fetched available markets for {len(song_market_data)} songs.")

# Convert to DataFrame
market_df = pd.DataFrame(song_market_data)

# Merge available markets with the existing dataset
df = df.merge(market_df, on="id", how="left")

# Save the updated dataset
df.to_csv("spotify_songs_with_markets.csv", index=False)

# Display dataset
import ace_tools as tools
tools.display_dataframe_to_user(name="Spotify Songs with Available Markets", dataframe=df)
# Out:
# 🌍 Fetching available markets for 169909 songs...
# Processing Songs:   0%|          | 0/169909 [00:00<?, ?song/s]WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 74049
# Processing Songs:   0%|          | 0/169909 [29:48<?, ?song/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-c488bdfb0eb7> in <cell line: 0>()
#      50         try:
#      51             # Fetch track details
# ---> 52             track = sp.track(song_id)
#      53
#      54             # Store available markets
#
# /usr/local/lib/python3.11/dist-packages/spotipy/client.py in track(self, track_id, market)
#     373
#     374         trid = self._get_id("track", track_id)
# --> 375         return self._get("tracks/" + trid, market=market)
#     376
#     377     def tracks(self, tracks, market=None):
#
# /usr/local/lib/python3.11/dist-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     325             kwargs.update(args)
#     326
# --> 327         return self._internal_call("GET", url, payload, kwargs)
#     328
#     329     def _post(self, url, args=None, payload=None, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     268
#     269         try:
# --> 270             response = self._session.request(
#     271                 method, url, headers=headers, proxies=self.proxies,
#     272                 timeout=self.requests_timeout, **args
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.11/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     938
#     939             response.drain_conn()
# --> 940             retries.sleep(response)
#     941             log.debug("Retry: %s", url)
#     942             return self.urlopen(
#
# /usr/local/lib/python3.11/dist-packages/urllib3/util/retry.py in sleep(self, response)
#     357
#     358         if self.respect_retry_after_header and response:
# --> 359             slept = self.sleep_for_retry(response)
#     360             if slept:
#     361                 return
#
# /usr/local/lib/python3.11/dist-packages/urllib3/util/retry.py in sleep_for_retry(self, response)
#     336         retry_after = self.get_retry_after(response)
#     337         if retry_after:
# --> 338             time.sleep(retry_after)
#     339             return True
#     340
#
# KeyboardInterrupt:

# %% [markdown]
# **Extracting all artists is not a viable option considering the strict API call time limitations of Spotify, the intended library, and the time restraint of this project. Thus a pre-acquired Spotify dataset will be used: https://www.kaggle.com/datasets/rodolfofigueroa/spotify-12m-songs**

# %% [markdown]
# ### Getting spotify_df on Kaggle

# %% [markdown]
# Downloading the 1.2 Million + spotify dataset on Kaggle: https://www.kaggle.com/datasets/rodolfofigueroa/spotify-12m-songs/data

# %% [markdown]
# ###Wesbcraping for Artist's Grammy Awards and Nominations -> grammy dataframe

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re

# Wikipedia page URL
url = "https://en.wikipedia.org/wiki/List_of_American_Grammy_Award_winners_and_nominees"

# Get the webpage content
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# Find the Grammy winners' table
tables = soup.find_all("table", {"class": "wikitable"})
if not tables:
    print("❌ No Grammy winners table found.")
    exit()

table = tables[0]  # Assuming the first table is correct

# Extract table rows
rows = table.find_all("tr")

# Initialize data storage
grammy_data = []

# Process table rows (skip header row)
for row in rows[1:]:
    cols = row.find_all(["th", "td"])
    if len(cols) < 3:
        continue  # Skip invalid rows

    # Extract text and clean it
    raw_artists = cols[0].get_text("\n", strip=True)  # Keep new lines as separators
    awards = cols[1].get_text(strip=True)
    nominations = cols[2].get_text(strip=True)

    # Remove unwanted references (e.g., [233], [note 2])
    raw_artists = re.sub(r"\[\d+\]|\[note \d+\]", "", raw_artists)  # Cleans out Wikipedia references

    # Ensure no leftover brackets or numbers
    raw_artists = re.sub(r"[\[\]]", "", raw_artists)  # Removes stray brackets

    # Split artists correctly based on new lines
    artists = raw_artists.split("\n")

    # Store cleaned data
    for artist in artists:
        artist = artist.strip()
        if artist and not artist.isnumeric():  # Exclude stray numbers
            grammy_data.append((artist, awards, nominations))

#moving onto the second table
table = tables[1]

rows = table.find_all("tr")

for row in rows[1:]:
    cols = row.find_all(["th", "td"])
    if len(cols) < 3:
        continue  # Skip invalid rows

    # Extract text and clean it
    raw_artists = cols[0].get_text("\n", strip=True)  # Keep new lines as separators
    awards = cols[1].get_text(strip=True)
    nominations = cols[2].get_text(strip=True)

    # Remove unwanted references (e.g., [233], [note 2])
    raw_artists = re.sub(r"\[\d+\]|\[note \d+\]", "", raw_artists)  # Cleans out Wikipedia references

    # Ensure no leftover brackets or numbers
    raw_artists = re.sub(r"[\[\]]", "", raw_artists)  # Removes stray brackets

    # Split artists correctly based on new lines
    artists = raw_artists.split("\n")

    # Store cleaned data
    for artist in artists:
        artist = artist.strip()
        if artist and not artist.isnumeric():  # Exclude stray numbers
            grammy_data.append((artist, awards, nominations))

# Convert to DataFrame
df = pd.DataFrame(grammy_data, columns=["Artist", "Grammy Awards", "Grammy Nominations"])

# Save to CSV
df.to_csv("grammy_winners_cleaned.csv", index=False)
